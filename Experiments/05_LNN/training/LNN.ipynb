# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# #Model

# %%
class LNN(nn.Module):
  def __init__(self):
    super().__init__()
    self.V = MLP_V()

  def forward(self, theta, omega):
    T = (1/2) * omega**2
    V = self.V(theta.unsqueeze(1)).squeeze()
    return T - V

class MLP_V(nn.Module):
  def __init__(self):
    super().__init__()
    self.net = nn.Sequential(
        nn.Linear(1, 128),
        nn.Tanh(),
        nn.Linear(128, 1),
    )

  def forward(self, theta):
    return self.net(theta)

# %% [markdown]
# #Training Loop

# %%
def lagrangian_dynamics(model, theta, omega):
  theta = theta.requires_grad_(True)
  omega = omega.requires_grad_(True)

  L = model(theta,omega).sum()

  dL_dtheta = torch.autograd.grad(L, theta, create_graph=True)[0]
  dL_domega = torch.autograd.grad(L, omega, create_graph=True)[0]

  d2L_d2omega = torch.autograd.grad(dL_domega.sum(), omega, create_graph=True)[0]

  eps = 1e-6
  domega = dL_dtheta / (d2L_d2omega + eps)
  dtheta = omega

  return dtheta,domega

# %%
#-------------
# Load data
#-------------

data = np.load("5.1_LNN_dataset.npz")
split = np.load("5.2_splits_LNN.npz")

X = np.hstack(data["X"])
X = X.reshape(15000, 2)
Y = data["Y"]
Y = Y.reshape(15000, 2)
print(X.shape)
print(Y.shape)

#----------------
# Split data
#----------------

X_train = X[split["train_idx"]]
Y_train = Y[split["train_idx"]]

X_test = X[split["test_idx"]]
Y_test = Y[split["test_idx"]]

#-------------------
# Convert to tensor
#-------------------

X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)

X_test = torch.tensor(X_test, dtype=torch.float32)
Y_test = torch.tensor(Y_test, dtype=torch.float32)

train_dataset = TensorDataset(X_train, Y_train)
test_dataset = TensorDataset(X_test, Y_test)

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

#---------
#  Model
#---------

model = LNN()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
loss_fn = nn.MSELoss()

#----------------
# Training loop
#----------------

n_epochs = 750

for epoch in range(n_epochs):
  model.train()
  train_loss = 0.0

  for X_batch, Y_batch in train_loader:

    theta = X_batch[:, 0]
    omega = X_batch[:, 1]

    dtheta_pred, domega_pred = lagrangian_dynamics(model, theta, omega)

    loss = (
        loss_fn(dtheta_pred, Y_batch[:,0]) +
        loss_fn(domega_pred, Y_batch[:,1])
    )

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    train_loss += loss.item()

  train_loss /= len(train_loader)


  model.eval()
  test_loss = 0.0

  for X_batch, Y_batch in test_loader:
      theta = X_batch[:,0]
      omega = X_batch[:,1]

      dtheta_pred, domega_pred = lagrangian_dynamics(model, theta, omega)

      loss = (
        loss_fn(dtheta_pred, Y_batch[:,0]) +
        loss_fn(domega_pred, Y_batch[:,1])
      )
      test_loss += loss.item()

  test_loss /= len(test_loader)
  print(f"Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")

#-------------
# Save model
#-------------

torch.save(model.state_dict(), "LNN.pth")
# Out:
# (15000, 2)
# (15000, 2)
# Epoch 1/750, Train Loss: 23.8024, Test Loss: 15.8175
# Epoch 2/750, Train Loss: 11.8133, Test Loss: 8.3123
# Epoch 3/750, Train Loss: 6.6405, Test Loss: 5.9479
# Epoch 4/750, Train Loss: 5.4519, Test Loss: 5.5541
# Epoch 5/750, Train Loss: 5.2117, Test Loss: 5.4295
# Epoch 6/750, Train Loss: 5.1286, Test Loss: 5.3520
# Epoch 7/750, Train Loss: 5.0718, Test Loss: 5.3108
# Epoch 8/750, Train Loss: 5.0204, Test Loss: 5.2763
# Epoch 9/750, Train Loss: 4.9872, Test Loss: 5.2423
# Epoch 10/750, Train Loss: 4.9596, Test Loss: 5.2132
# Epoch 11/750, Train Loss: 4.9437, Test Loss: 5.1920
# Epoch 12/750, Train Loss: 4.9056, Test Loss: 5.1145
# Epoch 13/750, Train Loss: 4.7421, Test Loss: 4.9712
# Epoch 14/750, Train Loss: 4.6105, Test Loss: 4.8363
# Epoch 15/750, Train Loss: 4.5040, Test Loss: 4.7369
# Epoch 16/750, Train Loss: 4.3734, Test Loss: 4.5824
# Epoch 17/750, Train Loss: 4.2632, Test Loss: 4.4737
# Epoch 18/750, Train Loss: 4.1551, Test Loss: 4.3685
# Epoch 19/750, Train Loss: 4.0461, Test Loss: 4.2496
# Epoch 20/750, Train Loss: 3.9594, Test Loss: 4.1909
# Epoch 21/750, Train Loss: 3.8939, Test Loss: 4.1219
# Epoch 22/750, Train Loss: 3.8312, Test Loss: 4.0486
# Epoch 23/750, Train Loss: 3.7752, Test Loss: 4.0034
# Epoch 24/750, Train Loss: 3.7454, Test Loss: 3.9708
# Epoch 25/750, Train Loss: 3.7204, Test Loss: 3.9496
# Epoch 26/750, Train Loss: 3.7062, Test Loss: 3.9272
# Epoch 27/750, Train Loss: 3.6794, Test Loss: 3.9013
# Epoch 28/750, Train Loss: 3.6518, Test Loss: 3.8810
# Epoch 29/750, Train Loss: 3.6488, Test Loss: 3.8777
# Epoch 30/750, Train Loss: 3.6400, Test Loss: 3.8759
# Epoch 31/750, Train Loss: 3.6303, Test Loss: 3.8441
# Epoch 32/750, Train Loss: 3.6130, Test Loss: 3.8342
# Epoch 33/750, Train Loss: 3.6027, Test Loss: 3.8255
# Epoch 34/750, Train Loss: 3.5923, Test Loss: 3.8033
# Epoch 35/750, Train Loss: 3.5789, Test Loss: 3.7759
# Epoch 36/750, Train Loss: 3.5663, Test Loss: 3.7582
# Epoch 37/750, Train Loss: 3.5422, Test Loss: 3.7071
# Epoch 38/750, Train Loss: 3.5139, Test Loss: 3.6823
# Epoch 39/750, Train Loss: 3.4956, Test Loss: 3.6379
# Epoch 40/750, Train Loss: 3.4551, Test Loss: 3.5888
# Epoch 41/750, Train Loss: 3.4300, Test Loss: 3.5673
# Epoch 42/750, Train Loss: 3.3980, Test Loss: 3.4921
# Epoch 43/750, Train Loss: 3.3597, Test Loss: 3.4599
# Epoch 44/750, Train Loss: 3.3244, Test Loss: 3.3854
# Epoch 45/750, Train Loss: 3.2856, Test Loss: 3.3619
# Epoch 46/750, Train Loss: 3.2591, Test Loss: 3.2836
# Epoch 47/750, Train Loss: 3.2149, Test Loss: 3.2320
# Epoch 48/750, Train Loss: 3.1915, Test Loss: 3.2004
# Epoch 49/750, Train Loss: 3.1491, Test Loss: 3.1287
# Epoch 50/750, Train Loss: 3.1247, Test Loss: 3.0885
# Epoch 51/750, Train Loss: 3.0861, Test Loss: 3.0388
# Epoch 52/750, Train Loss: 3.0619, Test Loss: 3.0170
# Epoch 53/750, Train Loss: 3.0424, Test Loss: 2.9901
# Epoch 54/750, Train Loss: 3.0123, Test Loss: 2.9389
# Epoch 55/750, Train Loss: 2.9888, Test Loss: 2.9244
# Epoch 56/750, Train Loss: 2.9697, Test Loss: 2.9263
# Epoch 57/750, Train Loss: 2.9518, Test Loss: 2.8835
# Epoch 58/750, Train Loss: 2.9428, Test Loss: 2.8480
# Epoch 59/750, Train Loss: 2.9266, Test Loss: 2.8231
# Epoch 60/750, Train Loss: 2.9088, Test Loss: 2.8371
# Epoch 61/750, Train Loss: 2.8930, Test Loss: 2.8118
# Epoch 62/750, Train Loss: 2.8856, Test Loss: 2.7799
# Epoch 63/750, Train Loss: 2.8744, Test Loss: 2.7716
# Epoch 64/750, Train Loss: 2.8417, Test Loss: 2.7271
# Epoch 65/750, Train Loss: 2.8352, Test Loss: 2.7579
# Epoch 66/750, Train Loss: 2.8091, Test Loss: 2.6947
# Epoch 67/750, Train Loss: 2.7922, Test Loss: 2.6698
# Epoch 68/750, Train Loss: 2.7669, Test Loss: 2.6482
# Epoch 69/750, Train Loss: 2.7504, Test Loss: 2.6344
# Epoch 70/750, Train Loss: 2.7201, Test Loss: 2.5910
# Epoch 71/750, Train Loss: 2.6850, Test Loss: 2.5661
# Epoch 72/750, Train Loss: 2.6643, Test Loss: 2.5807
# Epoch 73/750, Train Loss: 2.6436, Test Loss: 2.5294
# Epoch 74/750, Train Loss: 2.6040, Test Loss: 2.4960
# Epoch 75/750, Train Loss: 2.5910, Test Loss: 2.4751
# Epoch 76/750, Train Loss: 2.5733, Test Loss: 2.4839
# Epoch 77/750, Train Loss: 2.5526, Test Loss: 2.4346
# Epoch 78/750, Train Loss: 2.5113, Test Loss: 2.4169
# Epoch 79/750, Train Loss: 2.4867, Test Loss: 2.3953
# Epoch 80/750, Train Loss: 2.4759, Test Loss: 2.3761
# Epoch 81/750, Train Loss: 2.4566, Test Loss: 2.3547
# Epoch 82/750, Train Loss: 2.4357, Test Loss: 2.3232
# Epoch 83/750, Train Loss: 2.4029, Test Loss: 2.3207
# Epoch 84/750, Train Loss: 2.3770, Test Loss: 2.2731
# Epoch 85/750, Train Loss: 2.3552, Test Loss: 2.2726
# Epoch 86/750, Train Loss: 2.3185, Test Loss: 2.2191
# Epoch 87/750, Train Loss: 2.2887, Test Loss: 2.1978
# Epoch 88/750, Train Loss: 2.2697, Test Loss: 2.1439
# Epoch 89/750, Train Loss: 2.2201, Test Loss: 2.1107
# Epoch 90/750, Train Loss: 2.1787, Test Loss: 2.0616
# Epoch 91/750, Train Loss: 2.1423, Test Loss: 2.0360
# Epoch 92/750, Train Loss: 2.1084, Test Loss: 1.9984
# Epoch 93/750, Train Loss: 2.0798, Test Loss: 1.9800
# Epoch 94/750, Train Loss: 2.0563, Test Loss: 1.9537
# Epoch 95/750, Train Loss: 2.0346, Test Loss: 1.9651
# Epoch 96/750, Train Loss: 2.0070, Test Loss: 1.9059
# Epoch 97/750, Train Loss: 1.9797, Test Loss: 1.9246
# Epoch 98/750, Train Loss: 2.0036, Test Loss: 1.9198
# Epoch 99/750, Train Loss: 1.9559, Test Loss: 1.8643
# Epoch 100/750, Train Loss: 1.9375, Test Loss: 1.8444
# Epoch 101/750, Train Loss: 1.9317, Test Loss: 1.8516
# Epoch 102/750, Train Loss: 1.9239, Test Loss: 1.8325
# Epoch 103/750, Train Loss: 1.9176, Test Loss: 1.8408
# Epoch 104/750, Train Loss: 1.9315, Test Loss: 1.8516
# Epoch 105/750, Train Loss: 1.9038, Test Loss: 1.8139
# Epoch 106/750, Train Loss: 1.8973, Test Loss: 1.8111
# Epoch 107/750, Train Loss: 1.8906, Test Loss: 1.8013
# Epoch 108/750, Train Loss: 1.8881, Test Loss: 1.8211
# Epoch 109/750, Train Loss: 1.8831, Test Loss: 1.8144
# Epoch 110/750, Train Loss: 1.8991, Test Loss: 1.8105
# Epoch 111/750, Train Loss: 1.8753, Test Loss: 1.8080
# Epoch 112/750, Train Loss: 1.8770, Test Loss: 1.8113
# Epoch 113/750, Train Loss: 1.8709, Test Loss: 1.7801
# Epoch 114/750, Train Loss: 1.8776, Test Loss: 1.7858
# Epoch 115/750, Train Loss: 1.8643, Test Loss: 1.7851
# Epoch 116/750, Train Loss: 1.8647, Test Loss: 1.7947
# Epoch 117/750, Train Loss: 1.8626, Test Loss: 1.7839
# Epoch 118/750, Train Loss: 1.8640, Test Loss: 1.7806
# Epoch 119/750, Train Loss: 1.8676, Test Loss: 1.7913
# Epoch 120/750, Train Loss: 1.8644, Test Loss: 1.7889
# Epoch 121/750, Train Loss: 1.8553, Test Loss: 1.7684
# Epoch 122/750, Train Loss: 1.8546, Test Loss: 1.7721
# Epoch 123/750, Train Loss: 1.8495, Test Loss: 1.7741
# Epoch 124/750, Train Loss: 1.8524, Test Loss: 1.7718
# Epoch 125/750, Train Loss: 1.8496, Test Loss: 1.7641
# Epoch 126/750, Train Loss: 1.8524, Test Loss: 1.7709
# Epoch 127/750, Train Loss: 1.8507, Test Loss: 1.7692
# Epoch 128/750, Train Loss: 1.8619, Test Loss: 1.7642
# Epoch 129/750, Train Loss: 1.8538, Test Loss: 1.7769
# Epoch 130/750, Train Loss: 1.8537, Test Loss: 1.7630
# Epoch 131/750, Train Loss: 1.8452, Test Loss: 1.7588
# Epoch 132/750, Train Loss: 1.8457, Test Loss: 1.7688
# Epoch 133/750, Train Loss: 1.8417, Test Loss: 1.7603
# Epoch 134/750, Train Loss: 1.8363, Test Loss: 1.7592
# Epoch 135/750, Train Loss: 1.8404, Test Loss: 1.7568
# Epoch 136/750, Train Loss: 1.8437, Test Loss: 1.7570
# Epoch 137/750, Train Loss: 1.8362, Test Loss: 1.7564
# Epoch 138/750, Train Loss: 1.8377, Test Loss: 1.7654
# Epoch 139/750, Train Loss: 1.8413, Test Loss: 1.7605
# Epoch 140/750, Train Loss: 1.8447, Test Loss: 1.7639
# Epoch 141/750, Train Loss: 1.8458, Test Loss: 1.7621
# Epoch 142/750, Train Loss: 1.8308, Test Loss: 1.7554
# Epoch 143/750, Train Loss: 1.8337, Test Loss: 1.7591
# Epoch 144/750, Train Loss: 1.8326, Test Loss: 1.7755
# Epoch 145/750, Train Loss: 1.8410, Test Loss: 1.7500
# Epoch 146/750, Train Loss: 1.8365, Test Loss: 1.7492
# Epoch 147/750, Train Loss: 1.8303, Test Loss: 1.7465
# Epoch 148/750, Train Loss: 1.8311, Test Loss: 1.7572
# Epoch 149/750, Train Loss: 1.8300, Test Loss: 1.7585
# Epoch 150/750, Train Loss: 1.8301, Test Loss: 1.7487
# Epoch 151/750, Train Loss: 1.8275, Test Loss: 1.7432
# Epoch 152/750, Train Loss: 1.8221, Test Loss: 1.7492
# Epoch 153/750, Train Loss: 1.8230, Test Loss: 1.7498
# Epoch 154/750, Train Loss: 1.8289, Test Loss: 1.7548
# Epoch 155/750, Train Loss: 1.8216, Test Loss: 1.7540
# Epoch 156/750, Train Loss: 1.8248, Test Loss: 1.7463
# Epoch 157/750, Train Loss: 1.8269, Test Loss: 1.7501
# Epoch 158/750, Train Loss: 1.8212, Test Loss: 1.7480
# Epoch 159/750, Train Loss: 1.8259, Test Loss: 1.7436
# Epoch 160/750, Train Loss: 1.8203, Test Loss: 1.7420
# Epoch 161/750, Train Loss: 1.8251, Test Loss: 1.7464
# Epoch 162/750, Train Loss: 1.8219, Test Loss: 1.7412
# Epoch 163/750, Train Loss: 1.8215, Test Loss: 1.7389
# Epoch 164/750, Train Loss: 1.8179, Test Loss: 1.7380
# Epoch 165/750, Train Loss: 1.8182, Test Loss: 1.7395
# Epoch 166/750, Train Loss: 1.8135, Test Loss: 1.7331
# Epoch 167/750, Train Loss: 1.7635, Test Loss: 1.6707
# Epoch 168/750, Train Loss: 1.7231, Test Loss: 1.6527
# Epoch 169/750, Train Loss: 1.7163, Test Loss: 1.6392
# Epoch 170/750, Train Loss: 1.6897, Test Loss: 1.6349
# Epoch 171/750, Train Loss: 1.6727, Test Loss: 1.6122
# Epoch 172/750, Train Loss: 1.6558, Test Loss: 1.6190
# Epoch 173/750, Train Loss: 1.6506, Test Loss: 1.6227
# Epoch 174/750, Train Loss: 1.6632, Test Loss: 1.5942
# Epoch 175/750, Train Loss: 1.6415, Test Loss: 1.6011
# Epoch 176/750, Train Loss: 1.6323, Test Loss: 1.5803
# Epoch 177/750, Train Loss: 1.6104, Test Loss: 1.5784
# Epoch 178/750, Train Loss: 1.6114, Test Loss: 1.6083
# Epoch 179/750, Train Loss: 1.6026, Test Loss: 1.5723
# Epoch 180/750, Train Loss: 1.5929, Test Loss: 1.5655
# Epoch 181/750, Train Loss: 1.5885, Test Loss: 1.5504
# Epoch 182/750, Train Loss: 1.5829, Test Loss: 1.5971
# Epoch 183/750, Train Loss: 1.6263, Test Loss: 1.5707
# Epoch 184/750, Train Loss: 1.6060, Test Loss: 1.5953
# Epoch 185/750, Train Loss: 1.5751, Test Loss: 1.5422
# Epoch 186/750, Train Loss: 1.5659, Test Loss: 1.5573
# Epoch 187/750, Train Loss: 1.5667, Test Loss: 1.5413
# Epoch 188/750, Train Loss: 1.5687, Test Loss: 1.5622
# Epoch 189/750, Train Loss: 1.5556, Test Loss: 1.5632
# Epoch 190/750, Train Loss: 1.5593, Test Loss: 1.5600
# Epoch 191/750, Train Loss: 1.5579, Test Loss: 1.5443
# Epoch 192/750, Train Loss: 1.5479, Test Loss: 1.5348
# Epoch 193/750, Train Loss: 1.5428, Test Loss: 1.5303
# Epoch 194/750, Train Loss: 1.5406, Test Loss: 1.5290
# Epoch 195/750, Train Loss: 1.5400, Test Loss: 1.5209
# Epoch 196/750, Train Loss: 1.5328, Test Loss: 1.5140
# Epoch 197/750, Train Loss: 1.5460, Test Loss: 1.5221
# Epoch 198/750, Train Loss: 1.5410, Test Loss: 1.5250
# Epoch 199/750, Train Loss: 1.5399, Test Loss: 1.5214
# Epoch 200/750, Train Loss: 1.5413, Test Loss: 1.5334
# Epoch 201/750, Train Loss: 1.5393, Test Loss: 1.5228
# Epoch 202/750, Train Loss: 1.5385, Test Loss: 1.5255
# Epoch 203/750, Train Loss: 1.5292, Test Loss: 1.5104
# Epoch 204/750, Train Loss: 1.5395, Test Loss: 1.5327
# Epoch 205/750, Train Loss: 1.5292, Test Loss: 1.5230
# Epoch 206/750, Train Loss: 1.5332, Test Loss: 1.5130
# Epoch 207/750, Train Loss: 1.5349, Test Loss: 1.5124
# Epoch 208/750, Train Loss: 1.5231, Test Loss: 1.5187
# Epoch 209/750, Train Loss: 1.5227, Test Loss: 1.5188
# Epoch 210/750, Train Loss: 1.5426, Test Loss: 1.5024
# Epoch 211/750, Train Loss: 1.5209, Test Loss: 1.5102
# Epoch 212/750, Train Loss: 1.5271, Test Loss: 1.5032
# Epoch 213/750, Train Loss: 1.5280, Test Loss: 1.5090
# Epoch 214/750, Train Loss: 1.5245, Test Loss: 1.5061
# Epoch 215/750, Train Loss: 1.5259, Test Loss: 1.5128
# Epoch 216/750, Train Loss: 1.5283, Test Loss: 1.5091
# Epoch 217/750, Train Loss: 1.5274, Test Loss: 1.5002
# Epoch 218/750, Train Loss: 1.5253, Test Loss: 1.4960
# Epoch 219/750, Train Loss: 1.5155, Test Loss: 1.4996
# Epoch 220/750, Train Loss: 1.5123, Test Loss: 1.5015
# Epoch 221/750, Train Loss: 1.5147, Test Loss: 1.5046
# Epoch 222/750, Train Loss: 1.5158, Test Loss: 1.5270
# Epoch 223/750, Train Loss: 1.5217, Test Loss: 1.5029
# Epoch 224/750, Train Loss: 1.5155, Test Loss: 1.5104
# Epoch 225/750, Train Loss: 1.5128, Test Loss: 1.5154
# Epoch 226/750, Train Loss: 1.5255, Test Loss: 1.4922
# Epoch 227/750, Train Loss: 1.5117, Test Loss: 1.5025
# Epoch 228/750, Train Loss: 1.5147, Test Loss: 1.4958
# Epoch 229/750, Train Loss: 1.5153, Test Loss: 1.4918
# Epoch 230/750, Train Loss: 1.5125, Test Loss: 1.5020
# Epoch 231/750, Train Loss: 1.5178, Test Loss: 1.5057
# Epoch 232/750, Train Loss: 1.5163, Test Loss: 1.4975
# Epoch 233/750, Train Loss: 1.5246, Test Loss: 1.5232
# Epoch 234/750, Train Loss: 1.5189, Test Loss: 1.4947
# Epoch 235/750, Train Loss: 1.5127, Test Loss: 1.5096
# Epoch 236/750, Train Loss: 1.5138, Test Loss: 1.5298
# Epoch 237/750, Train Loss: 1.5135, Test Loss: 1.5053
# Epoch 238/750, Train Loss: 1.5121, Test Loss: 1.5197
# Epoch 239/750, Train Loss: 1.5132, Test Loss: 1.5011
# Epoch 240/750, Train Loss: 1.5104, Test Loss: 1.5004
# Epoch 241/750, Train Loss: 1.5125, Test Loss: 1.4870
# Epoch 242/750, Train Loss: 1.5048, Test Loss: 1.4933
# Epoch 243/750, Train Loss: 1.5129, Test Loss: 1.4898
# Epoch 244/750, Train Loss: 1.5163, Test Loss: 1.5024
# Epoch 245/750, Train Loss: 1.5157, Test Loss: 1.5073
# Epoch 246/750, Train Loss: 1.5272, Test Loss: 1.5018
# Epoch 247/750, Train Loss: 1.5113, Test Loss: 1.4907
# Epoch 248/750, Train Loss: 1.5216, Test Loss: 1.5073
# Epoch 249/750, Train Loss: 1.5049, Test Loss: 1.5234
# Epoch 250/750, Train Loss: 1.5074, Test Loss: 1.4928
# Epoch 251/750, Train Loss: 1.5123, Test Loss: 1.5082
# Epoch 252/750, Train Loss: 1.5154, Test Loss: 1.5146
# Epoch 253/750, Train Loss: 1.5096, Test Loss: 1.4896
# Epoch 254/750, Train Loss: 1.5105, Test Loss: 1.5007
# Epoch 255/750, Train Loss: 1.5084, Test Loss: 1.5076
# Epoch 256/750, Train Loss: 1.5138, Test Loss: 1.4986
# Epoch 257/750, Train Loss: 1.5010, Test Loss: 1.4938
# Epoch 258/750, Train Loss: 1.5000, Test Loss: 1.4924
# Epoch 259/750, Train Loss: 1.5016, Test Loss: 1.4848
# Epoch 260/750, Train Loss: 1.5196, Test Loss: 1.5102
# Epoch 261/750, Train Loss: 1.5174, Test Loss: 1.5068
# Epoch 262/750, Train Loss: 1.5007, Test Loss: 1.4809
# Epoch 263/750, Train Loss: 1.5005, Test Loss: 1.4856
# Epoch 264/750, Train Loss: 1.5030, Test Loss: 1.4837
# Epoch 265/750, Train Loss: 1.5004, Test Loss: 1.4794
# Epoch 266/750, Train Loss: 1.5116, Test Loss: 1.4897
# Epoch 267/750, Train Loss: 1.5026, Test Loss: 1.4845
# Epoch 268/750, Train Loss: 1.5014, Test Loss: 1.4879
# Epoch 269/750, Train Loss: 1.5064, Test Loss: 1.4911
# Epoch 270/750, Train Loss: 1.4959, Test Loss: 1.4941
# Epoch 271/750, Train Loss: 1.4995, Test Loss: 1.4859
# Epoch 272/750, Train Loss: 1.5039, Test Loss: 1.4866
# Epoch 273/750, Train Loss: 1.5018, Test Loss: 1.5204
# Epoch 274/750, Train Loss: 1.5042, Test Loss: 1.4821
# Epoch 275/750, Train Loss: 1.4960, Test Loss: 1.4816
# Epoch 276/750, Train Loss: 1.4990, Test Loss: 1.4825
# Epoch 277/750, Train Loss: 1.4981, Test Loss: 1.5063
# Epoch 278/750, Train Loss: 1.5107, Test Loss: 1.4906
# Epoch 279/750, Train Loss: 1.5010, Test Loss: 1.4863
# Epoch 280/750, Train Loss: 1.4993, Test Loss: 1.4845
# Epoch 281/750, Train Loss: 1.5049, Test Loss: 1.4846
# Epoch 282/750, Train Loss: 1.5024, Test Loss: 1.5007
# Epoch 283/750, Train Loss: 1.5065, Test Loss: 1.4822
# Epoch 284/750, Train Loss: 1.4974, Test Loss: 1.5144
# Epoch 285/750, Train Loss: 1.5051, Test Loss: 1.4775
# Epoch 286/750, Train Loss: 1.4936, Test Loss: 1.4960
# Epoch 287/750, Train Loss: 1.5012, Test Loss: 1.4866
# Epoch 288/750, Train Loss: 1.4991, Test Loss: 1.4945
# Epoch 289/750, Train Loss: 1.4961, Test Loss: 1.4809
# Epoch 290/750, Train Loss: 1.5107, Test Loss: 1.4865
# Epoch 291/750, Train Loss: 1.5010, Test Loss: 1.4932
# Epoch 292/750, Train Loss: 1.5033, Test Loss: 1.4974
# Epoch 293/750, Train Loss: 1.4986, Test Loss: 1.4897
# Epoch 294/750, Train Loss: 1.5033, Test Loss: 1.4780
# Epoch 295/750, Train Loss: 1.5044, Test Loss: 1.4801
# Epoch 296/750, Train Loss: 1.4955, Test Loss: 1.4853
# Epoch 297/750, Train Loss: 1.4977, Test Loss: 1.4908
# Epoch 298/750, Train Loss: 1.4997, Test Loss: 1.4758
# Epoch 299/750, Train Loss: 1.4978, Test Loss: 1.4783
# Epoch 300/750, Train Loss: 1.4917, Test Loss: 1.4882
# Epoch 301/750, Train Loss: 1.5081, Test Loss: 1.5118
# Epoch 302/750, Train Loss: 1.4975, Test Loss: 1.4920
# Epoch 303/750, Train Loss: 1.4979, Test Loss: 1.4754
# Epoch 304/750, Train Loss: 1.4920, Test Loss: 1.4766
# Epoch 305/750, Train Loss: 1.4913, Test Loss: 1.4796
# Epoch 306/750, Train Loss: 1.4967, Test Loss: 1.4913
# Epoch 307/750, Train Loss: 1.4976, Test Loss: 1.4865
# Epoch 308/750, Train Loss: 1.4981, Test Loss: 1.4821
# Epoch 309/750, Train Loss: 1.4902, Test Loss: 1.4756
# Epoch 310/750, Train Loss: 1.5068, Test Loss: 1.4939
# Epoch 311/750, Train Loss: 1.5073, Test Loss: 1.4960
# Epoch 312/750, Train Loss: 1.4906, Test Loss: 1.4872
# Epoch 313/750, Train Loss: 1.4967, Test Loss: 1.4990
# Epoch 314/750, Train Loss: 1.5038, Test Loss: 1.5090
# Epoch 315/750, Train Loss: 1.5055, Test Loss: 1.5150
# Epoch 316/750, Train Loss: 1.4945, Test Loss: 1.4808
# Epoch 317/750, Train Loss: 1.4954, Test Loss: 1.4816
# Epoch 318/750, Train Loss: 1.4928, Test Loss: 1.4734
# Epoch 319/750, Train Loss: 1.4892, Test Loss: 1.4807
# Epoch 320/750, Train Loss: 1.4916, Test Loss: 1.4726
# Epoch 321/750, Train Loss: 1.4940, Test Loss: 1.4731
# Epoch 322/750, Train Loss: 1.4860, Test Loss: 1.4712
# Epoch 323/750, Train Loss: 1.4904, Test Loss: 1.4731
# Epoch 324/750, Train Loss: 1.4923, Test Loss: 1.4834
# Epoch 325/750, Train Loss: 1.4905, Test Loss: 1.4780
# Epoch 326/750, Train Loss: 1.4904, Test Loss: 1.4737
# Epoch 327/750, Train Loss: 1.4881, Test Loss: 1.4751
# Epoch 328/750, Train Loss: 1.4881, Test Loss: 1.4749
# Epoch 329/750, Train Loss: 1.4945, Test Loss: 1.4704
# Epoch 330/750, Train Loss: 1.4919, Test Loss: 1.4822
# Epoch 331/750, Train Loss: 1.4880, Test Loss: 1.4802
# Epoch 332/750, Train Loss: 1.4947, Test Loss: 1.4813
# Epoch 333/750, Train Loss: 1.4904, Test Loss: 1.4780
# Epoch 334/750, Train Loss: 1.4883, Test Loss: 1.4699
# Epoch 335/750, Train Loss: 1.4960, Test Loss: 1.4816
# Epoch 336/750, Train Loss: 1.4942, Test Loss: 1.4736
# Epoch 337/750, Train Loss: 1.4943, Test Loss: 1.4897
# Epoch 338/750, Train Loss: 1.4989, Test Loss: 1.4762
# Epoch 339/750, Train Loss: 1.4931, Test Loss: 1.4701
# Epoch 340/750, Train Loss: 1.4854, Test Loss: 1.4850
# Epoch 341/750, Train Loss: 1.4917, Test Loss: 1.4739
# Epoch 342/750, Train Loss: 1.4950, Test Loss: 1.4910
# Epoch 343/750, Train Loss: 1.4881, Test Loss: 1.4736
# Epoch 344/750, Train Loss: 1.4883, Test Loss: 1.4747
# Epoch 345/750, Train Loss: 1.4992, Test Loss: 1.4898
# Epoch 346/750, Train Loss: 1.4984, Test Loss: 1.4740
# Epoch 347/750, Train Loss: 1.4874, Test Loss: 1.4671
# Epoch 348/750, Train Loss: 1.4941, Test Loss: 1.4697
# Epoch 349/750, Train Loss: 1.4860, Test Loss: 1.4744
# Epoch 350/750, Train Loss: 1.4902, Test Loss: 1.4831
# Epoch 351/750, Train Loss: 1.4941, Test Loss: 1.4698
# Epoch 352/750, Train Loss: 1.4854, Test Loss: 1.4709
# Epoch 353/750, Train Loss: 1.4885, Test Loss: 1.4757
# Epoch 354/750, Train Loss: 1.4947, Test Loss: 1.4829
# Epoch 355/750, Train Loss: 1.4987, Test Loss: 1.4716
# Epoch 356/750, Train Loss: 1.4919, Test Loss: 1.4731
# Epoch 357/750, Train Loss: 1.4876, Test Loss: 1.4709
# Epoch 358/750, Train Loss: 1.4828, Test Loss: 1.4802
# Epoch 359/750, Train Loss: 1.4906, Test Loss: 1.4871
# Epoch 360/750, Train Loss: 1.4913, Test Loss: 1.4674
# Epoch 361/750, Train Loss: 1.4862, Test Loss: 1.4827
# Epoch 362/750, Train Loss: 1.4850, Test Loss: 1.4868
# Epoch 363/750, Train Loss: 1.4864, Test Loss: 1.4645
# Epoch 364/750, Train Loss: 1.4820, Test Loss: 1.4673
# Epoch 365/750, Train Loss: 1.4835, Test Loss: 1.4761
# Epoch 366/750, Train Loss: 1.4857, Test Loss: 1.4775
# Epoch 367/750, Train Loss: 1.5058, Test Loss: 1.4757
# Epoch 368/750, Train Loss: 1.4909, Test Loss: 1.4772
# Epoch 369/750, Train Loss: 1.4846, Test Loss: 1.4829
# Epoch 370/750, Train Loss: 1.4887, Test Loss: 1.4790
# Epoch 371/750, Train Loss: 1.4822, Test Loss: 1.4747
# Epoch 372/750, Train Loss: 1.4831, Test Loss: 1.4666
# Epoch 373/750, Train Loss: 1.4874, Test Loss: 1.4758
# Epoch 374/750, Train Loss: 1.4855, Test Loss: 1.4689
# Epoch 375/750, Train Loss: 1.4876, Test Loss: 1.4714
# Epoch 376/750, Train Loss: 1.4853, Test Loss: 1.4671
# Epoch 377/750, Train Loss: 1.4821, Test Loss: 1.4693
# Epoch 378/750, Train Loss: 1.4814, Test Loss: 1.4656
# Epoch 379/750, Train Loss: 1.4811, Test Loss: 1.4816
# Epoch 380/750, Train Loss: 1.4936, Test Loss: 1.4877
# Epoch 381/750, Train Loss: 1.4874, Test Loss: 1.4836
# Epoch 382/750, Train Loss: 1.4852, Test Loss: 1.4676
# Epoch 383/750, Train Loss: 1.4857, Test Loss: 1.4668
# Epoch 384/750, Train Loss: 1.4897, Test Loss: 1.4672
# Epoch 385/750, Train Loss: 1.4826, Test Loss: 1.4726
# Epoch 386/750, Train Loss: 1.4837, Test Loss: 1.4812
# Epoch 387/750, Train Loss: 1.4919, Test Loss: 1.4667
# Epoch 388/750, Train Loss: 1.4852, Test Loss: 1.4792
# Epoch 389/750, Train Loss: 1.4843, Test Loss: 1.4677
# Epoch 390/750, Train Loss: 1.4856, Test Loss: 1.4701
# Epoch 391/750, Train Loss: 1.4839, Test Loss: 1.4824
# Epoch 392/750, Train Loss: 1.4878, Test Loss: 1.4688
# Epoch 393/750, Train Loss: 1.4840, Test Loss: 1.4686
# Epoch 394/750, Train Loss: 1.4922, Test Loss: 1.4726
# Epoch 395/750, Train Loss: 1.4884, Test Loss: 1.4777
# Epoch 396/750, Train Loss: 1.4838, Test Loss: 1.4705
# Epoch 397/750, Train Loss: 1.4844, Test Loss: 1.4711
# Epoch 398/750, Train Loss: 1.4958, Test Loss: 1.5137
# Epoch 399/750, Train Loss: 1.4908, Test Loss: 1.4873
# Epoch 400/750, Train Loss: 1.4894, Test Loss: 1.4688
# Epoch 401/750, Train Loss: 1.4818, Test Loss: 1.4640
# Epoch 402/750, Train Loss: 1.4806, Test Loss: 1.4867
# Epoch 403/750, Train Loss: 1.4920, Test Loss: 1.4892
# Epoch 404/750, Train Loss: 1.4827, Test Loss: 1.4725
# Epoch 405/750, Train Loss: 1.4907, Test Loss: 1.4756
# Epoch 406/750, Train Loss: 1.4881, Test Loss: 1.4669
# Epoch 407/750, Train Loss: 1.4860, Test Loss: 1.4705
# Epoch 408/750, Train Loss: 1.4860, Test Loss: 1.4807
# Epoch 409/750, Train Loss: 1.4805, Test Loss: 1.4654
# Epoch 410/750, Train Loss: 1.4865, Test Loss: 1.4743
# Epoch 411/750, Train Loss: 1.4995, Test Loss: 1.4936
# Epoch 412/750, Train Loss: 1.5062, Test Loss: 1.4855
# Epoch 413/750, Train Loss: 1.4872, Test Loss: 1.4645
# Epoch 414/750, Train Loss: 1.4794, Test Loss: 1.4695
# Epoch 415/750, Train Loss: 1.4821, Test Loss: 1.4614
# Epoch 416/750, Train Loss: 1.4770, Test Loss: 1.4746
# Epoch 417/750, Train Loss: 1.4879, Test Loss: 1.4813
# Epoch 418/750, Train Loss: 1.4947, Test Loss: 1.4996
# Epoch 419/750, Train Loss: 1.4879, Test Loss: 1.4614
# Epoch 420/750, Train Loss: 1.4767, Test Loss: 1.4729
# Epoch 421/750, Train Loss: 1.4828, Test Loss: 1.4641
# Epoch 422/750, Train Loss: 1.4779, Test Loss: 1.4619
# Epoch 423/750, Train Loss: 1.4826, Test Loss: 1.4605
# Epoch 424/750, Train Loss: 1.4849, Test Loss: 1.4678
# Epoch 425/750, Train Loss: 1.4838, Test Loss: 1.4652
# Epoch 426/750, Train Loss: 1.4891, Test Loss: 1.4783
# Epoch 427/750, Train Loss: 1.4867, Test Loss: 1.4728
# Epoch 428/750, Train Loss: 1.4817, Test Loss: 1.4624
# Epoch 429/750, Train Loss: 1.4866, Test Loss: 1.4611
# Epoch 430/750, Train Loss: 1.4854, Test Loss: 1.4638
# Epoch 431/750, Train Loss: 1.4813, Test Loss: 1.4653
# Epoch 432/750, Train Loss: 1.4796, Test Loss: 1.4763
# Epoch 433/750, Train Loss: 1.4868, Test Loss: 1.4643
# Epoch 434/750, Train Loss: 1.4822, Test Loss: 1.4619
# Epoch 435/750, Train Loss: 1.4830, Test Loss: 1.4643
# Epoch 436/750, Train Loss: 1.4793, Test Loss: 1.4599
# Epoch 437/750, Train Loss: 1.4761, Test Loss: 1.4613
# Epoch 438/750, Train Loss: 1.4791, Test Loss: 1.4601
# Epoch 439/750, Train Loss: 1.4815, Test Loss: 1.4602
# Epoch 440/750, Train Loss: 1.4882, Test Loss: 1.4933
# Epoch 441/750, Train Loss: 1.4891, Test Loss: 1.4640
# Epoch 442/750, Train Loss: 1.4819, Test Loss: 1.5361
# Epoch 443/750, Train Loss: 1.4814, Test Loss: 1.4548
# Epoch 444/750, Train Loss: 1.4758, Test Loss: 1.4695
# Epoch 445/750, Train Loss: 1.4886, Test Loss: 1.4694
# Epoch 446/750, Train Loss: 1.4838, Test Loss: 1.4604
# Epoch 447/750, Train Loss: 1.4828, Test Loss: 1.4621
# Epoch 448/750, Train Loss: 1.4836, Test Loss: 1.4644
# Epoch 449/750, Train Loss: 1.4798, Test Loss: 1.4647
# Epoch 450/750, Train Loss: 1.4924, Test Loss: 1.4869
# Epoch 451/750, Train Loss: 1.4901, Test Loss: 1.4813
# Epoch 452/750, Train Loss: 1.4794, Test Loss: 1.4600
# Epoch 453/750, Train Loss: 1.4775, Test Loss: 1.4622
# Epoch 454/750, Train Loss: 1.4835, Test Loss: 1.4617
# Epoch 455/750, Train Loss: 1.4780, Test Loss: 1.4632
# Epoch 456/750, Train Loss: 1.4858, Test Loss: 1.4729
# Epoch 457/750, Train Loss: 1.4770, Test Loss: 1.4616
# Epoch 458/750, Train Loss: 1.4863, Test Loss: 1.4883
# Epoch 459/750, Train Loss: 1.5012, Test Loss: 1.4663
# Epoch 460/750, Train Loss: 1.4767, Test Loss: 1.4627
# Epoch 461/750, Train Loss: 1.4827, Test Loss: 1.4825
# Epoch 462/750, Train Loss: 1.4851, Test Loss: 1.4633
# Epoch 463/750, Train Loss: 1.4757, Test Loss: 1.4691
# Epoch 464/750, Train Loss: 1.4823, Test Loss: 1.4598
# Epoch 465/750, Train Loss: 1.4828, Test Loss: 1.4605
# Epoch 466/750, Train Loss: 1.4846, Test Loss: 1.4601
# Epoch 467/750, Train Loss: 1.4766, Test Loss: 1.4601
# Epoch 468/750, Train Loss: 1.4829, Test Loss: 1.4682
# Epoch 469/750, Train Loss: 1.4854, Test Loss: 1.4578
# Epoch 470/750, Train Loss: 1.4752, Test Loss: 1.4581
# Epoch 471/750, Train Loss: 1.4803, Test Loss: 1.4802
# Epoch 472/750, Train Loss: 1.4813, Test Loss: 1.4643
# Epoch 473/750, Train Loss: 1.4826, Test Loss: 1.4722
# Epoch 474/750, Train Loss: 1.4832, Test Loss: 1.4670
# Epoch 475/750, Train Loss: 1.4804, Test Loss: 1.4648
# Epoch 476/750, Train Loss: 1.4804, Test Loss: 1.4754
# Epoch 477/750, Train Loss: 1.4800, Test Loss: 1.4580
# Epoch 478/750, Train Loss: 1.4766, Test Loss: 1.4572
# Epoch 479/750, Train Loss: 1.4841, Test Loss: 1.4732
# Epoch 480/750, Train Loss: 1.4809, Test Loss: 1.4587
# Epoch 481/750, Train Loss: 1.4845, Test Loss: 1.4667
# Epoch 482/750, Train Loss: 1.4787, Test Loss: 1.4676
# Epoch 483/750, Train Loss: 1.4761, Test Loss: 1.4624
# Epoch 484/750, Train Loss: 1.4745, Test Loss: 1.4601
# Epoch 485/750, Train Loss: 1.4717, Test Loss: 1.4682
# Epoch 486/750, Train Loss: 1.4781, Test Loss: 1.4640
# Epoch 487/750, Train Loss: 1.4747, Test Loss: 1.4601
# Epoch 488/750, Train Loss: 1.4802, Test Loss: 1.4611
# Epoch 489/750, Train Loss: 1.4854, Test Loss: 1.4691
# Epoch 490/750, Train Loss: 1.4789, Test Loss: 1.4608
# Epoch 491/750, Train Loss: 1.4890, Test Loss: 1.4600
# Epoch 492/750, Train Loss: 1.4830, Test Loss: 1.4659
# Epoch 493/750, Train Loss: 1.4778, Test Loss: 1.4647
# Epoch 494/750, Train Loss: 1.4802, Test Loss: 1.4578
# Epoch 495/750, Train Loss: 1.4794, Test Loss: 1.4633
# Epoch 496/750, Train Loss: 1.4747, Test Loss: 1.4599
# Epoch 497/750, Train Loss: 1.4828, Test Loss: 1.4598
# Epoch 498/750, Train Loss: 1.4797, Test Loss: 1.4739
# Epoch 499/750, Train Loss: 1.4826, Test Loss: 1.4627
# Epoch 500/750, Train Loss: 1.4803, Test Loss: 1.4618
# Epoch 501/750, Train Loss: 1.4823, Test Loss: 1.4627
# Epoch 502/750, Train Loss: 1.4796, Test Loss: 1.4650
# Epoch 503/750, Train Loss: 1.4909, Test Loss: 1.5766
# Epoch 504/750, Train Loss: 1.5111, Test Loss: 1.5026
# Epoch 505/750, Train Loss: 1.4997, Test Loss: 1.4680
# Epoch 506/750, Train Loss: 1.4819, Test Loss: 1.4588
# Epoch 507/750, Train Loss: 1.4838, Test Loss: 1.4750
# Epoch 508/750, Train Loss: 1.4835, Test Loss: 1.4587
# Epoch 509/750, Train Loss: 1.4855, Test Loss: 1.4623
# Epoch 510/750, Train Loss: 1.4780, Test Loss: 1.4693
# Epoch 511/750, Train Loss: 1.4799, Test Loss: 1.4839
# Epoch 512/750, Train Loss: 1.4845, Test Loss: 1.4623
# Epoch 513/750, Train Loss: 1.4796, Test Loss: 1.4622
# Epoch 514/750, Train Loss: 1.4835, Test Loss: 1.4680
# Epoch 515/750, Train Loss: 1.4816, Test Loss: 1.4616
# Epoch 516/750, Train Loss: 1.4824, Test Loss: 1.4680
# Epoch 517/750, Train Loss: 1.4828, Test Loss: 1.4672
# Epoch 518/750, Train Loss: 1.4754, Test Loss: 1.4551
# Epoch 519/750, Train Loss: 1.4833, Test Loss: 1.4692
# Epoch 520/750, Train Loss: 1.4805, Test Loss: 1.4590
# Epoch 521/750, Train Loss: 1.4830, Test Loss: 1.4594
# Epoch 522/750, Train Loss: 1.4851, Test Loss: 1.4589
# Epoch 523/750, Train Loss: 1.4782, Test Loss: 1.4724
# Epoch 524/750, Train Loss: 1.4759, Test Loss: 1.4555
# Epoch 525/750, Train Loss: 1.4784, Test Loss: 1.4802
# Epoch 526/750, Train Loss: 1.4803, Test Loss: 1.4635
# Epoch 527/750, Train Loss: 1.4743, Test Loss: 1.4597
# Epoch 528/750, Train Loss: 1.4782, Test Loss: 1.4580
# Epoch 529/750, Train Loss: 1.4816, Test Loss: 1.4587
# Epoch 530/750, Train Loss: 1.4763, Test Loss: 1.4611
# Epoch 531/750, Train Loss: 1.4760, Test Loss: 1.4637
# Epoch 532/750, Train Loss: 1.4820, Test Loss: 1.4650
# Epoch 533/750, Train Loss: 1.4765, Test Loss: 1.4641
# Epoch 534/750, Train Loss: 1.4787, Test Loss: 1.4565
# Epoch 535/750, Train Loss: 1.4830, Test Loss: 1.4719
# Epoch 536/750, Train Loss: 1.4808, Test Loss: 1.4651
# Epoch 537/750, Train Loss: 1.4796, Test Loss: 1.4609
# Epoch 538/750, Train Loss: 1.4760, Test Loss: 1.4761
# Epoch 539/750, Train Loss: 1.4825, Test Loss: 1.4818
# Epoch 540/750, Train Loss: 1.4820, Test Loss: 1.4706
# Epoch 541/750, Train Loss: 1.4771, Test Loss: 1.4585
# Epoch 542/750, Train Loss: 1.4808, Test Loss: 1.4557
# Epoch 543/750, Train Loss: 1.4803, Test Loss: 1.4591
# Epoch 544/750, Train Loss: 1.4757, Test Loss: 1.4601
# Epoch 545/750, Train Loss: 1.4821, Test Loss: 1.4573
# Epoch 546/750, Train Loss: 1.4901, Test Loss: 1.4690
# Epoch 547/750, Train Loss: 1.4826, Test Loss: 1.4660
# Epoch 548/750, Train Loss: 1.4859, Test Loss: 1.4667
# Epoch 549/750, Train Loss: 1.4799, Test Loss: 1.4613
# Epoch 550/750, Train Loss: 1.4803, Test Loss: 1.4703
# Epoch 551/750, Train Loss: 1.4777, Test Loss: 1.4568
# Epoch 552/750, Train Loss: 1.4801, Test Loss: 1.4723
# Epoch 553/750, Train Loss: 1.4818, Test Loss: 1.4607
# Epoch 554/750, Train Loss: 1.4882, Test Loss: 1.4765
# Epoch 555/750, Train Loss: 1.4828, Test Loss: 1.4596
# Epoch 556/750, Train Loss: 1.4791, Test Loss: 1.4694
# Epoch 557/750, Train Loss: 1.4796, Test Loss: 1.4569
# Epoch 558/750, Train Loss: 1.4805, Test Loss: 1.4608
# Epoch 559/750, Train Loss: 1.4775, Test Loss: 1.4611
# Epoch 560/750, Train Loss: 1.4878, Test Loss: 1.4634
# Epoch 561/750, Train Loss: 1.4855, Test Loss: 1.4800
# Epoch 562/750, Train Loss: 1.4772, Test Loss: 1.4612
# Epoch 563/750, Train Loss: 1.4756, Test Loss: 1.4623
# Epoch 564/750, Train Loss: 1.4862, Test Loss: 1.4642
# Epoch 565/750, Train Loss: 1.4801, Test Loss: 1.4570
# Epoch 566/750, Train Loss: 1.4780, Test Loss: 1.4597
# Epoch 567/750, Train Loss: 1.4774, Test Loss: 1.4666
# Epoch 568/750, Train Loss: 1.4767, Test Loss: 1.4638
# Epoch 569/750, Train Loss: 1.4775, Test Loss: 1.4632
# Epoch 570/750, Train Loss: 1.4757, Test Loss: 1.4655
# Epoch 571/750, Train Loss: 1.4762, Test Loss: 1.4765
# Epoch 572/750, Train Loss: 1.4837, Test Loss: 1.4627
# Epoch 573/750, Train Loss: 1.4811, Test Loss: 1.4705
# Epoch 574/750, Train Loss: 1.4797, Test Loss: 1.4646
# Epoch 575/750, Train Loss: 1.4778, Test Loss: 1.4562
# Epoch 576/750, Train Loss: 1.4780, Test Loss: 1.4654
# Epoch 577/750, Train Loss: 1.4811, Test Loss: 1.4574
# Epoch 578/750, Train Loss: 1.4764, Test Loss: 1.4550
# Epoch 579/750, Train Loss: 1.4754, Test Loss: 1.4610
# Epoch 580/750, Train Loss: 1.4831, Test Loss: 1.4591
# Epoch 581/750, Train Loss: 1.4800, Test Loss: 1.4557
# Epoch 582/750, Train Loss: 1.4766, Test Loss: 1.4585
# Epoch 583/750, Train Loss: 1.4823, Test Loss: 1.4709
# Epoch 584/750, Train Loss: 1.4887, Test Loss: 1.4776
# Epoch 585/750, Train Loss: 1.4778, Test Loss: 1.4574
# Epoch 586/750, Train Loss: 1.4767, Test Loss: 1.4597
# Epoch 587/750, Train Loss: 1.4796, Test Loss: 1.4561
# Epoch 588/750, Train Loss: 1.4771, Test Loss: 1.4608
# Epoch 589/750, Train Loss: 1.4782, Test Loss: 1.4604
# Epoch 590/750, Train Loss: 1.4799, Test Loss: 1.4597
# Epoch 591/750, Train Loss: 1.4734, Test Loss: 1.4653
# Epoch 592/750, Train Loss: 1.4835, Test Loss: 1.4626
# Epoch 593/750, Train Loss: 1.4810, Test Loss: 1.4592
# Epoch 594/750, Train Loss: 1.4810, Test Loss: 1.4635
# Epoch 595/750, Train Loss: 1.4781, Test Loss: 1.4685
# Epoch 596/750, Train Loss: 1.4836, Test Loss: 1.4660
# Epoch 597/750, Train Loss: 1.4767, Test Loss: 1.4577
# Epoch 598/750, Train Loss: 1.4892, Test Loss: 1.4656
# Epoch 599/750, Train Loss: 1.4816, Test Loss: 1.4593
# Epoch 600/750, Train Loss: 1.4749, Test Loss: 1.4586
# Epoch 601/750, Train Loss: 1.4758, Test Loss: 1.4631
# Epoch 602/750, Train Loss: 1.4766, Test Loss: 1.4627
# Epoch 603/750, Train Loss: 1.4772, Test Loss: 1.4582
# Epoch 604/750, Train Loss: 1.4806, Test Loss: 1.4623
# Epoch 605/750, Train Loss: 1.4766, Test Loss: 1.4582
# Epoch 606/750, Train Loss: 1.4699, Test Loss: 1.4545
# Epoch 607/750, Train Loss: 1.4772, Test Loss: 1.4586
# Epoch 608/750, Train Loss: 1.4825, Test Loss: 1.4633
# Epoch 609/750, Train Loss: 1.4731, Test Loss: 1.4562
# Epoch 610/750, Train Loss: 1.4814, Test Loss: 1.4547
# Epoch 611/750, Train Loss: 1.4872, Test Loss: 1.4623
# Epoch 612/750, Train Loss: 1.4804, Test Loss: 1.4689
# Epoch 613/750, Train Loss: 1.4761, Test Loss: 1.4612
# Epoch 614/750, Train Loss: 1.4765, Test Loss: 1.4576
# Epoch 615/750, Train Loss: 1.4776, Test Loss: 1.4650
# Epoch 616/750, Train Loss: 1.4863, Test Loss: 1.4720
# Epoch 617/750, Train Loss: 1.4803, Test Loss: 1.4827
# Epoch 618/750, Train Loss: 1.4847, Test Loss: 1.4601
# Epoch 619/750, Train Loss: 1.4750, Test Loss: 1.4580
# Epoch 620/750, Train Loss: 1.4783, Test Loss: 1.4588
# Epoch 621/750, Train Loss: 1.4771, Test Loss: 1.4616
# Epoch 622/750, Train Loss: 1.4761, Test Loss: 1.4617
# Epoch 623/750, Train Loss: 1.4747, Test Loss: 1.4592
# Epoch 624/750, Train Loss: 1.4731, Test Loss: 1.4667
# Epoch 625/750, Train Loss: 1.4807, Test Loss: 1.4643
# Epoch 626/750, Train Loss: 1.4828, Test Loss: 1.4641
# Epoch 627/750, Train Loss: 1.4886, Test Loss: 1.4899
# Epoch 628/750, Train Loss: 1.4807, Test Loss: 1.4564
# Epoch 629/750, Train Loss: 1.4799, Test Loss: 1.4540
# Epoch 630/750, Train Loss: 1.4731, Test Loss: 1.4539
# Epoch 631/750, Train Loss: 1.4744, Test Loss: 1.4599
# Epoch 632/750, Train Loss: 1.4797, Test Loss: 1.4617
# Epoch 633/750, Train Loss: 1.4791, Test Loss: 1.4620
# Epoch 634/750, Train Loss: 1.4812, Test Loss: 1.4656
# Epoch 635/750, Train Loss: 1.4779, Test Loss: 1.4679
# Epoch 636/750, Train Loss: 1.4785, Test Loss: 1.4576
# Epoch 637/750, Train Loss: 1.4807, Test Loss: 1.4777
# Epoch 638/750, Train Loss: 1.4782, Test Loss: 1.4672
# Epoch 639/750, Train Loss: 1.4747, Test Loss: 1.4649
# Epoch 640/750, Train Loss: 1.4715, Test Loss: 1.4615
# Epoch 641/750, Train Loss: 1.4777, Test Loss: 1.4636
# Epoch 642/750, Train Loss: 1.4749, Test Loss: 1.4576
# Epoch 643/750, Train Loss: 1.4805, Test Loss: 1.4593
# Epoch 644/750, Train Loss: 1.4761, Test Loss: 1.4558
# Epoch 645/750, Train Loss: 1.4861, Test Loss: 1.4929
# Epoch 646/750, Train Loss: 1.4790, Test Loss: 1.4603
# Epoch 647/750, Train Loss: 1.4876, Test Loss: 1.4744
# Epoch 648/750, Train Loss: 1.4775, Test Loss: 1.4568
# Epoch 649/750, Train Loss: 1.4743, Test Loss: 1.4585
# Epoch 650/750, Train Loss: 1.4805, Test Loss: 1.4791
# Epoch 651/750, Train Loss: 1.4821, Test Loss: 1.4730
# Epoch 652/750, Train Loss: 1.4825, Test Loss: 1.4664
# Epoch 653/750, Train Loss: 1.4771, Test Loss: 1.4573
# Epoch 654/750, Train Loss: 1.4804, Test Loss: 1.4670
# Epoch 655/750, Train Loss: 1.4889, Test Loss: 1.4800
# Epoch 656/750, Train Loss: 1.4793, Test Loss: 1.4584
# Epoch 657/750, Train Loss: 1.4793, Test Loss: 1.4593
# Epoch 658/750, Train Loss: 1.4748, Test Loss: 1.4543
# Epoch 659/750, Train Loss: 1.4742, Test Loss: 1.4715
# Epoch 660/750, Train Loss: 1.4790, Test Loss: 1.4549
# Epoch 661/750, Train Loss: 1.4758, Test Loss: 1.4618
# Epoch 662/750, Train Loss: 1.4799, Test Loss: 1.4541
# Epoch 663/750, Train Loss: 1.4733, Test Loss: 1.4560
# Epoch 664/750, Train Loss: 1.4860, Test Loss: 1.4736
# Epoch 665/750, Train Loss: 1.4925, Test Loss: 1.4586
# Epoch 666/750, Train Loss: 1.4763, Test Loss: 1.4524
# Epoch 667/750, Train Loss: 1.4752, Test Loss: 1.4593
# Epoch 668/750, Train Loss: 1.4756, Test Loss: 1.4566
# Epoch 669/750, Train Loss: 1.4865, Test Loss: 1.4901
# Epoch 670/750, Train Loss: 1.4814, Test Loss: 1.4595
# Epoch 671/750, Train Loss: 1.4779, Test Loss: 1.4607
# Epoch 672/750, Train Loss: 1.4756, Test Loss: 1.4567
# Epoch 673/750, Train Loss: 1.4767, Test Loss: 1.4644
# Epoch 674/750, Train Loss: 1.4829, Test Loss: 1.4578
# Epoch 675/750, Train Loss: 1.4789, Test Loss: 1.4629
# Epoch 676/750, Train Loss: 1.4784, Test Loss: 1.4550
# Epoch 677/750, Train Loss: 1.4760, Test Loss: 1.4665
# Epoch 678/750, Train Loss: 1.4820, Test Loss: 1.4907
# Epoch 679/750, Train Loss: 1.4821, Test Loss: 1.4614
# Epoch 680/750, Train Loss: 1.4797, Test Loss: 1.4602
# Epoch 681/750, Train Loss: 1.4785, Test Loss: 1.4638
# Epoch 682/750, Train Loss: 1.4776, Test Loss: 1.4594
# Epoch 683/750, Train Loss: 1.4765, Test Loss: 1.4601
# Epoch 684/750, Train Loss: 1.4749, Test Loss: 1.4595
# Epoch 685/750, Train Loss: 1.4715, Test Loss: 1.4533
# Epoch 686/750, Train Loss: 1.4771, Test Loss: 1.4631
# Epoch 687/750, Train Loss: 1.4758, Test Loss: 1.4564
# Epoch 688/750, Train Loss: 1.4745, Test Loss: 1.4570
# Epoch 689/750, Train Loss: 1.4803, Test Loss: 1.4596
# Epoch 690/750, Train Loss: 1.4762, Test Loss: 1.4560
# Epoch 691/750, Train Loss: 1.4880, Test Loss: 1.4685
# Epoch 692/750, Train Loss: 1.4796, Test Loss: 1.4601
# Epoch 693/750, Train Loss: 1.4785, Test Loss: 1.4557
# Epoch 694/750, Train Loss: 1.4760, Test Loss: 1.4570
# Epoch 695/750, Train Loss: 1.4793, Test Loss: 1.4588
# Epoch 696/750, Train Loss: 1.4741, Test Loss: 1.4548
# Epoch 697/750, Train Loss: 1.4765, Test Loss: 1.4652
# Epoch 698/750, Train Loss: 1.4773, Test Loss: 1.4584
# Epoch 699/750, Train Loss: 1.4791, Test Loss: 1.4923
# Epoch 700/750, Train Loss: 1.4831, Test Loss: 1.4572
# Epoch 701/750, Train Loss: 1.4778, Test Loss: 1.4543
# Epoch 702/750, Train Loss: 1.4774, Test Loss: 1.4702
# Epoch 703/750, Train Loss: 1.4754, Test Loss: 1.4577
# Epoch 704/750, Train Loss: 1.4847, Test Loss: 1.4590
# Epoch 705/750, Train Loss: 1.4739, Test Loss: 1.4529
# Epoch 706/750, Train Loss: 1.4767, Test Loss: 1.4582
# Epoch 707/750, Train Loss: 1.4799, Test Loss: 1.4679
# Epoch 708/750, Train Loss: 1.4834, Test Loss: 1.4631
# Epoch 709/750, Train Loss: 1.4833, Test Loss: 1.4738
# Epoch 710/750, Train Loss: 1.4834, Test Loss: 1.4826
# Epoch 711/750, Train Loss: 1.4809, Test Loss: 1.4557
# Epoch 712/750, Train Loss: 1.4791, Test Loss: 1.4572
# Epoch 713/750, Train Loss: 1.4742, Test Loss: 1.4555
# Epoch 714/750, Train Loss: 1.4735, Test Loss: 1.4544
# Epoch 715/750, Train Loss: 1.4702, Test Loss: 1.4578
# Epoch 716/750, Train Loss: 1.4774, Test Loss: 1.4632
# Epoch 717/750, Train Loss: 1.4874, Test Loss: 1.4585
# Epoch 718/750, Train Loss: 1.4786, Test Loss: 1.4546
# Epoch 719/750, Train Loss: 1.4809, Test Loss: 1.4581
# Epoch 720/750, Train Loss: 1.4780, Test Loss: 1.4598
# Epoch 721/750, Train Loss: 1.4784, Test Loss: 1.4662
# Epoch 722/750, Train Loss: 1.4762, Test Loss: 1.4573
# Epoch 723/750, Train Loss: 1.4731, Test Loss: 1.4616
# Epoch 724/750, Train Loss: 1.4862, Test Loss: 1.4892
# Epoch 725/750, Train Loss: 1.4875, Test Loss: 1.4601
# Epoch 726/750, Train Loss: 1.4747, Test Loss: 1.4576
# Epoch 727/750, Train Loss: 1.4756, Test Loss: 1.4531
# Epoch 728/750, Train Loss: 1.4778, Test Loss: 1.4535
# Epoch 729/750, Train Loss: 1.4778, Test Loss: 1.4548
# Epoch 730/750, Train Loss: 1.4734, Test Loss: 1.4632
# Epoch 731/750, Train Loss: 1.4761, Test Loss: 1.4630
# Epoch 732/750, Train Loss: 1.4789, Test Loss: 1.4532
# Epoch 733/750, Train Loss: 1.4757, Test Loss: 1.4628
# Epoch 734/750, Train Loss: 1.4785, Test Loss: 1.4626
# Epoch 735/750, Train Loss: 1.4786, Test Loss: 1.4634
# Epoch 736/750, Train Loss: 1.4787, Test Loss: 1.4683
# Epoch 737/750, Train Loss: 1.4753, Test Loss: 1.4567
# Epoch 738/750, Train Loss: 1.4767, Test Loss: 1.4532
# Epoch 739/750, Train Loss: 1.4841, Test Loss: 1.4716
# Epoch 740/750, Train Loss: 1.4785, Test Loss: 1.4646
# Epoch 741/750, Train Loss: 1.4770, Test Loss: 1.4556
# Epoch 742/750, Train Loss: 1.4967, Test Loss: 1.4801
# Epoch 743/750, Train Loss: 1.4810, Test Loss: 1.4584
# Epoch 744/750, Train Loss: 1.4822, Test Loss: 1.4649
# Epoch 745/750, Train Loss: 1.4763, Test Loss: 1.4540
# Epoch 746/750, Train Loss: 1.4753, Test Loss: 1.4601
# Epoch 747/750, Train Loss: 1.4764, Test Loss: 1.4633
# Epoch 748/750, Train Loss: 1.4743, Test Loss: 1.4540
# Epoch 749/750, Train Loss: 1.4732, Test Loss: 1.4528
# Epoch 750/750, Train Loss: 1.4757, Test Loss: 1.4618

# %% [markdown]
# #Results

# %%
def pendulum_dynamics(x, u, params):  # Compute the function f(x,t) such that theta'' = f(x,t)
  theta, omega = x
  m, l, g = params["m"], params["l"], params["g"]
  u = float(u)

  d_theta = omega
  d_omega = (g/l) * np.sin(theta) + u/(m * l**2)

  return np.array([d_theta, d_omega])

def rk4_step(f, x, u, dt, params):  # Compute the position after a short time dt based on the pervious position using rk4 method
  k1 = f(x, u, params)
  k2 = f(x + 0.5 * dt * k1, u, params)
  k3 = f(x + 0.5 * dt * k2, u, params)
  k4 = f(x + dt * k3, u, params)

  return x + (dt/6)*(k1 + 2*k2 + 2*k3 + k4)

def trajectory_simulation(x0, u_control, dt, T, params):  # Compute the trajectory using rk4_step at each step
  N = int(T/dt)
  x = np.zeros((N+1, 2))
  x[0] = x0

  for t in range(N):
    u = u_control(t * dt, x[t])
    x[t+1] = rk4_step(pendulum_dynamics, x[t], u, dt, params)
  return x


def zero_control(t,x):
  return 0

def rk4_step_LNN(model, x, dt):
    if x.dim() == 1:
        x = x.unsqueeze(0)
    def f(x):
        theta, omega = x[:,0], x[:,1]
        dtheta, domega = lagrangian_dynamics(model, theta, omega)
        return torch.stack([dtheta, domega], dim=1)

    k1 = f(x)
    k2 = f(x + 0.5 * dt * k1)
    k3 = f(x + 0.5 * dt * k2)
    k4 = f(x + dt * k3)
    return x + (dt/6)*(k1 + 2*k2 + 2*k3 + k4)

def trajectory_simulation_LNN(x0, dt, T):  # adapted version for the HNN
    N = int(T / dt)
    x = torch.zeros((N+1, 2))
    x[0] = torch.tensor(x0, dtype=torch.float32)

    for t in range(N):
        x[t+1] = rk4_step_LNN(model, x[t], dt).detach()

    return x.detach().numpy()

# %%
#--------------
# Parameters
#--------------

params = {
    "g": 9.81,   # gravity (m/s^2)
    "l": 1.0,    # lenght (m)
    "m": 1.0     # mass (kg)
}

x0 = [3, 2.1]

HNN_trajectory = []
true_trajectory = []
T = 10.0 # 10s
dt = 0.01 # 500 step

#--------------
# Trajectories
#--------------

HNN_trajectory = trajectory_simulation_LNN(x0, dt, T)

true_trajectory = trajectory_simulation(x0, zero_control, dt, T, params=params)

#-------
# Plot
#-------

t = np.arange(start=0, stop = 10.001, step = dt)

print(HNN_trajectory.shape)
print(true_trajectory.shape)
print(t.shape)

plt.plot(t, np.array(HNN_trajectory)[:,0], "--")
plt.plot(t, np.array(true_trajectory)[:,0])
plt.xlabel("Time (s)")
plt.ylabel("Theta (rad)")
plt.legend(["LNN", "True"])
plt.show()

plt.plot(t, np.array(HNN_trajectory)[:,1], "--")
plt.plot(t, np.array(true_trajectory)[:,1])
plt.xlabel("Time (s)")
plt.ylabel("Omega (rad/s)")
plt.legend(["LNN", "True"])
plt.show()

plt.figure()
plt.plot(np.array(HNN_trajectory)[:,0], np.array(HNN_trajectory)[:,1], "--")
plt.plot(np.array(true_trajectory)[:,0], np.array(true_trajectory)[:,1])
plt.legend(["LNN", "True"])
plt.xlabel("Theta (rad)")
plt.ylabel("Omega (rad/s)")
plt.show()
# Out:
# (1001, 2)
# (1001, 2)
# (1001,)
